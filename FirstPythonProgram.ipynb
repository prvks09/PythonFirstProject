# %% [markdown]
# # my first python code

# %% [markdown]
# # To convert to py use below command
# ## jupyter nbconvert --to script your_notebook.ipynb

# %%
print("Hello World")
# Out:
# Hello World

# %%
for i in range(1,5):
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
celsius_temperature = []
celsius_temperature.append(25)
celsius_temperature.append(54)
print(celsius_temperature)
# Out:
# [25, 54]

# %%
def calculate_area(length, breadth):
    area = length * breadth
    return area

print(f"Area is: {calculate_area(4,8)}")
# Out:
# Area is: 32
